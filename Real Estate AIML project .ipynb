# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc
import sklearn as sk

# %%
df = pd.read_csv("USA_Housing.csv")

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   str
# dtypes: float64(6), str(1)
# memory usage: 499.6 KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.isna().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.drop(columns = ["brokered_by", "zip_code","prev_sold_date"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop(columns = ["brokered_by", "zip_code","prev_sold_date"], inplace = True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# ...

# %%
df
# Out:
#            status     price  bed  bath  acre_lot     street        city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0    Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0    Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0  Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0       Ponce
# 4        for_sale   65000.0  6.0   2.0      0.05   331151.0    Mayaguez
# ...           ...       ...  ...   ...       ...        ...         ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0    Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0    Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0    Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0    Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0    Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# 1        Puerto Rico      1527.0
# ...

# %%
df.shape
# Out:
# (2226382, 9)

# %%
df.isna().sum()
# Out:
# status             0
# price           1541
# bed           481317
# bath          511771
# acre_lot      325589
# street         10866
# city            1407
# state              8
# house_size    568484
# dtype: int64

# %%
df.isna().sum(). sum()
# Out:
# 1900983

# %%
df.dropna(inplace = True)

# %%
df.isna().sum(). sum()
# Out:
# 0

# %%
df.head()
# Out:
#      status     price  bed  bath  acre_lot     street           city  \
# 0  for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1  for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2  for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3  for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5  for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
#
#          state  house_size
# 0  Puerto Rico       920.0
# 1  Puerto Rico      1527.0
# 2  Puerto Rico       748.0
# 3  Puerto Rico      1800.0
# 5  Puerto Rico      2520.0

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 5          False
#            ...
# 2226377    False
# 2226378    False
# 2226379    False
# 2226380    False
# 2226381    False
# Length: 1356397, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 535

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
df.duplicated() .sum()
# Out:
# 0

# %%
df.head()
# Out:
#      status     price  bed  bath  acre_lot     street           city  \
# 0  for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1  for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2  for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3  for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5  for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
#
#          state  house_size
# 0  Puerto Rico       920.0
# 1  Puerto Rico      1527.0
# 2  Puerto Rico       748.0
# 3  Puerto Rico      1800.0
# 5  Puerto Rico      2520.0

# %%
df["status"].value_counts()
# Out:
# status
# for_sale    747459
# sold        608403
# Name: count, dtype: int64

# %%
df["state"].value_counts()
# Out:
# state
# California              170550
# Texas                   145188
# Florida                 126328
# Arizona                  54475
# Pennsylvania             51847
# New York                 50697
# Georgia                  49134
# Illinois                 46640
# Washington               46336
# Virginia                 44159
# Ohio                     41147
# North Carolina           37329
# Maryland                 32927
# Minnesota                32682
# Missouri                 30071
# Massachusetts            28051
# Oklahoma                 26824
# Michigan                 22092
# Oregon                   21854
# Colorado                 19527
# New Jersey               19453
# Wisconsin                18427
# Tennessee                18288
# South Carolina           17176
# Iowa                     16492
# Kentucky                 15718
# Alabama                  14674
# Louisiana                14467
# New Mexico               11822
# Idaho                    11556
# ...

# %%
df["state"].value_counts().sort_values(ascending=True). head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %%
df["state"].value_counts().sort_values(ascending=False). head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %%
df["state"].value_counts().sort_values(ascending=True). head(10).plot(kind='bar')
plt.title('Number of Houses by state')
plt.ylabel('Listing Number')
plt.xlabel('State')
plt.show()

# %%
df
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
df.groupby('state')['price'].mean().sort_values(ascending = False).astype(int)
# Out:
# state
# Virgin Islands          1947522
# Hawaii                  1491548
# District of Columbia    1209649
# California              1107572
# Colorado                 952486
# Utah                     914531
# Montana                  862815
# Connecticut              790488
# Massachusetts            754230
# Nevada                   751439
# Washington               727478
# Wyoming                  719581
# Guam                     717504
# Idaho                    689815
# New York                 657557
# Florida                  649977
# Oregon                   645160
# New Hampshire            640991
# Puerto Rico              632210
# Vermont                  557932
# Arizona                  552891
# Virginia                 546274
# Alaska                   541288
# New Jersey               541131
# Maine                    517891
# Rhode Island             511094
# Maryland                 502889
# South Carolina           485025
# Tennessee                485018
# ...

# %%
df
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
df.groupby('city')['price'].mean().sort_values(ascending = False).astype(int)
# Out:
# city
# International      2147483600
# Bolingbroke          45250000
# Bal Harbour          26585714
# Gulf Stream          21461250
# Woody Creek          20987500
#                       ...
# Otter Rock              10033
# Midwest                 10000
# Center Junction          8500
# Rowan                    7500
# Pilot Mound              6500
# Name: price, Length: 17114, dtype: int32

# %%
df.groupby(['state','city'])['price'].mean().reset_index()
# Out:
#          state        city         price
# 0      Alabama   Abbeville  2.201540e+05
# 1      Alabama  Adamsville  1.384411e+05
# 2      Alabama     Addison  1.459500e+05
# 3      Alabama       Adger  1.743727e+05
# 4      Alabama       Akron  4.389400e+05
# ...        ...         ...           ...
# 26255  Wyoming   Wheatland  2.815783e+05
# 26256  Wyoming      Wilson  5.719900e+06
# 26257  Wyoming     Worland  2.889077e+05
# 26258  Wyoming      Wright  2.911600e+05
# 26259  Wyoming       Yoder  3.406667e+05
#
# [26260 rows x 3 columns]

# %%
df
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
df.select_dtypes(include=['number']).corr()["price"]
# Out:
# price         1.000000
# bed           0.117585
# bath          0.208868
# acre_lot      0.005304
# street        0.000481
# house_size    0.073849
# Name: price, dtype: float64

# %%
x=df[['bed','bath','house_size']]
x
# Out:
#          bed  bath  house_size
# 0        3.0   2.0       920.0
# 1        4.0   2.0      1527.0
# 2        2.0   1.0       748.0
# 3        4.0   2.0      1800.0
# 5        4.0   3.0      2520.0
# ...      ...   ...         ...
# 2226377  4.0   2.0      3600.0
# 2226378  3.0   2.0      1616.0
# 2226379  6.0   3.0      3200.0
# 2226380  2.0   1.0       933.0
# 2226381  5.0   3.0      3615.0
#
# [1355862 rows x 3 columns]

# %%
y=df['price']
y
# Out:
# 0          105000.0
# 1           80000.0
# 2           67000.0
# 3          145000.0
# 5          179000.0
#              ...
# 2226377    359900.0
# 2226378    350000.0
# 2226379    440000.0
# 2226380    179900.0
# 2226381    580000.0
# Name: price, Length: 1355862, dtype: float64

# %%
x.columns
# Out:
# Index(['bed', 'bath', 'house_size'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
len(y_train)
# Out:
# 1084689

# %%
len(y_test)
# Out:
# 271173

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %%
x_train
# Out:
#           bed  bath  house_size
# 1780261   4.0   3.0      2760.0
# 231000    3.0   2.0      1024.0
# 1568847   3.0   4.0      1904.0
# 1289131   2.0   2.0       827.0
# 1310002   3.0   2.0      1572.0
# ...       ...   ...         ...
# 1921766   3.0   2.0      1730.0
# 1102546   3.0   2.0      1483.0
# 1315296   3.0   2.0      1642.0
# 1376624  10.0   8.0      5170.0
# 563926    3.0   3.0      1845.0
#
# [1084689 rows x 3 columns]

# %%
x_test
# Out:
#          bed  bath  house_size
# 295770   4.0   3.0      2546.0
# 87387    3.0   2.0      1616.0
# 1932582  3.0   2.0      1749.0
# 303852   3.0   3.0      1883.0
# 1409217  6.0   3.0      3467.0
# ...      ...   ...         ...
# 1265151  2.0   2.0      1005.0
# 1391302  4.0   5.0      5490.0
# 2098678  2.0   3.0      1417.0
# 1478596  2.0   2.0      2364.0
# 181568   3.0   1.0      1398.0
#
# [271173 rows x 3 columns]

# %%
x_train = st.fit_transform(x_train)
x_train
# Out:
# array([[ 0.44068391,  0.33657999,  0.16607685],
#        [-0.27699712, -0.39837675, -0.28390913],
#        [-0.27699712,  1.07153673, -0.05580564],
#        ...,
#        [-0.27699712, -0.39837675, -0.12371827],
#        [ 4.74677013,  4.01136368,  0.79076935],
#        [-0.27699712,  0.33657999, -0.07109894]])

# %%
import joblib
joblib.dump(st,"st.pkl")
# Out:
# ['st.pkl']

# %%
x_test = st.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions =  lr.predict(x_test)
# Out:
# C:\documents\New folder\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 743335.5987072816

# %%
df['price'].describe().astype(int)
# Out:
# count       1355862
# mean         574225
# std         2212087
# min               0
# 25%          239000
# 50%          379000
# 75%          600000
# max      2147483600
# Name: price, dtype: int32

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']

# %%
# !pip install streamlit
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-auth 2.28.1 requires cachetools<6.0,>=2.0.0, but you have cachetools 7.0.5 which is incompatible.
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/dc/e6/412c1e1f200ca8c32ecf10201839183e261ad61ced3ede34a66f6d4be3cf/streamlit-1.55.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair!=5.4.0,!=5.4.1,<7,>=4.0 from https://files.pythonhosted.org/packages/db/33/ef2f2409450ef6daa61459d5de5c08128e7d3edb773fefd0a324d1310238/altair-6.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.5.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
# ...

# %%
import streamlit as st1
import numpy as np
import joblib

# %%
st = joblib.load('st.pkl')

# %%
model = joblib.load('model.pkl')

# %%
st1.title ('Real Estate Price Prediction App')
# Out:
# 2026-03-31 16:12:10.446 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:12:11.056
# ...
#   command:
#
#     streamlit run C:\documents\New folder\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-31 16:12:11.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:12:11.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st1.divider()
# Out:
# 2026-03-31 16:12:31.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:12:31.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:12:31.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
bed = st1.number_input('Enter The number of bedrooms',value=2,step=1)
# Out:
# 2026-03-31 16:13:30.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:13:30.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:13:30.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:13:30.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:13:30.880 Session state does not function when running a script without `streamlit run`
# 2026-03-31 16:13:30.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:13:30.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:13:30.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
bath=st1.number_input('Enter the number of bathrooms', value=1,step=1)
# Out:
# 2026-03-31 16:14:17.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:14:17.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:14:17.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:14:17.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:14:17.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:14:17.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:14:17.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
size=st1.number_input('Enter the size', value=1000, step=50)
# Out:
# 2026-03-31 16:15:00.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:15:00.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:15:00.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:15:00.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:15:00.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:15:00.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:15:00.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
x=[bed,bath,size]

# %%
st1.divider ()
# Out:
# 2026-03-31 16:16:26.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:16:26.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:16:26.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
predictbutton = st1.button ("Predict")
# Out:
# 2026-03-31 16:18:45.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:45.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:45.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:45.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:45.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:45.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st1.divider ()
# Out:
# 2026-03-31 16:18:48.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:48.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 16:18:48.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
if predictbutton:
    st1.balloons()
    x1 = np.array(x)
    x_array = st.transform([x1])
    prediction = model.predict(x_array)[0]
    st1.write(f'the prediction is{prediction :.2f}')
    
else: 
    "please use the button for prediction "
